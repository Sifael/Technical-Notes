# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
fig, ax = plt.figure(), plt.axes()

# %%
fig, ax = plt.figure(), plt.axes()

for i in range(1, 4):
    ax.plot([0, i], [i, i])

# %%
fig, ax = plt.figure( facecolor='lightblue', frameon=True, edgecolor='green', layout = 'tight' ), plt.axes()
