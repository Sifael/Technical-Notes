# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure( figsize=(2, 3), facecolor="gray" )
ax = plt.axes( facecolor="lightyellow" )

# %%
import numpy as np

# %%
x = np.linspace( 0, 1, 2 )

# %%
fig , ax = plt.figure(figsize=(8,4)), plt.axes()
ax.plot(x, x)
ax.plot(x, 1-x)
ax.set_title("Some Chart")
# Out:
# Text(0.5, 1.0, 'Some Chart')

# %%
ax.get_title()
# Out:
# 'Some Chart'
